# %%
from modulefinder import ModuleFinder

finder = ModuleFinder()
finder.run_script('c:\datascience\MultiProcess.py')

print('Loaded modules:')
for name, mod in finder.modules.items():
    print(('%s: ' % name))
    print((','.join(list(mod.globalnames.keys())[:3])))

print(('-'*50))
print('Modules not imported:')
print(('\n'.join(iter(finder.badmodules.keys()))))
# Out:
# Loaded modules:
# __main__:
# Pool,TimeoutError,time
# multiprocessing:
# sys,context,__all__
# sys:
#
# multiprocessing.context:
# os,sys,threading
# os:
# __doc__,abc,sys
# abc:
# __doc__,abstractmethod,abstractclassmethod
# _abc:
#
# _py_abc:
# WeakSet,get_cache_token,ABCMeta
# _weakrefset:
# ref,__all__,_IterationGuard
# _weakref:
#
# stat:
# __doc__,ST_MODE,ST_INO
# _stat:
#
# _collections_abc:
# __doc__,ABCMeta,abstractmethod
# posixpath:
# __doc__,curdir,pardir
# genericpath:
# __doc__,os,stat
# re:
# __doc__,enum,sre_compile
# enum:
# sys,MappingProxyType,DynamicClassAttribute
# types:
# __doc__,sys,_f
# functools:
# __doc__,__all__,reduce
# _functools:
#
# collections:
# __doc__,__all__,_collections_abc
# operator:
# __doc__,__all__,_abs
# builtins:
#
# _operator:
#
# keyword:
# __doc__,__all__,kwlist
# heapq:
# __doc__,__about__,__all__
# _heapq:
#
# doctest:
# __doc__,__docformat__,__all__
# __future__:
# __doc__,all_feature_names,__all__
# difflib:
# __doc__,__all__,_nlargest
# inspect:
# __doc__,__author__,abc
# dis:
# __doc__,sys,types
# io:
# __doc__,__author__,__all__
# _io:
#
# opcode:
# __doc__,__all__,stack_effect
# _opcode:
#
# argparse:
# __doc__,__version__,__all__
# gettext:
# __doc__,locale,os
# locale:
# __doc__,sys,encodings
# encodings:
# __doc__,codecs,sys
# codecs:
# __doc__,builtins,sys
# _codecs:
#
# encodings.aliases:
# __doc__,aliases
# _winapi:
#
# encodings.mbcs:
# __doc__,mbcs_encode,mbcs_decode
# _locale:
#
# warnings:
# __doc__,sys,__all__
# _warnings:
#
# linecache:
# __doc__,functools,sys
# tokenize:
# __doc__,__author__,__credits__
# itertools:
#
# token:
# __doc__,__all__,ENDMARKER
# tracemalloc:
# Sequence,Iterable,total_ordering
# collections.abc:
# __doc__,ABCMeta,abstractmethod
# fnmatch:
# __doc__,os,posixpath
# pickle:
# __doc__,FunctionType,dispatch_table
# copyreg:
# __doc__,__all__,dispatch_table
# struct:
# __all__,_clearcache,__doc__
# _struct:
#
# _compat_pickle:
# IMPORT_MAPPING,NAME_MAPPING,PYTHON2_EXCEPTIONS
# _pickle:
#
# pprint:
# __doc__,_collections,re
# time:
#
# _tracemalloc:
#
# traceback:
# __doc__,collections,itertools
# _bootlocale:
# __doc__,sys,_locale
# errno:
#
# copy:
# __doc__,types,weakref
# weakref:
# __doc__,getweakrefcount,getweakrefs
# atexit:
#
# gc:
#
# textwrap:
# __doc__,re,__all__
# importlib:
# __doc__,__all__,_imp
# _imp:
#
# importlib._bootstrap:
# __doc__,_bootstrap_external,_wrap
# importlib._bootstrap_external:
# __doc__,_CASE_INSENSITIVE_PLATFORMS_STR_KEY,_CASE_INSENSITIVE_PLATFORMS_BYTES_KEY
# importlib.machinery:
# __doc__,_imp,ModuleSpec
# ast:
# __doc__,parse,literal_eval
# _ast:
#
# pdb:
# __doc__,os,re
# cmd:
# __doc__,string,sys
# string:
# __doc__,__all__,_string
# _string:
#
# readline:
# print_function,unicode_literals,absolute_import
# pyreadline:
# print_function,unicode_literals,absolute_import
# pyreadline.unicode_helper:
# sys,unicode,bytes
# pyreadline.py3k_compat:
# print_function,unicode_literals,absolute_import
# pyreadline.logger:
# print_function,unicode_literals,absolute_import
# socket:
# __doc__,_socket,os
# _socket:
#
# selectors:
# __doc__,ABCMeta,abstractmethod
# math:
#
# select:
#
# logging:
# __doc__,sys,os
# threading:
# __doc__,_os,_sys
# _thread:
#
# _collections:
#
# _threading_local:
# __doc__,ref,contextmanager
# contextlib:
# __doc__,abc,sys
# logging.handlers:
# __doc__,logging,socket
# queue:
# __doc__,threading,deque
# _queue:
#
# smtplib:
# __doc__,socket,io
# email:
# __doc__,__all__,message_from_string
# email.parser:
# __doc__,__all__,StringIO
# email.feedparser:
# __doc__,__all__,re
# email.errors:
# __doc__,MessageError,MessageParseError
# email._policybase:
# __doc__,abc,header
# email.header:
# __doc__,__all__,re
# binascii:
#
# email.quoprimime:
# __doc__,__all__,re
# email.base64mime:
# __doc__,__all__,b64encode
# base64:
# __doc__,re,struct
# getopt:
# __doc__,__all__,os
# email.charset:
# __all__,partial,email
# email.encoders:
# __doc__,__all__,_bencode
# quopri:
# __doc__,__all__,ESCAPE
# email.utils:
# __doc__,__all__,os
# random:
# __doc__,_warn,_MethodType
# hashlib:
# __doc__,__always_supported,algorithms_guaranteed
# _hashlib:
#
# _sha1:
#
# _md5:
#
# _sha256:
#
# _sha512:
#
# _blake2:
#
# _sha3:
#
# bisect:
# __doc__,insort_right,bisect_right
# _bisect:
#
# _random:
#
# datetime:
# __doc__,_time,_math
# _datetime:
#
# _strptime:
# __doc__,time,locale
# calendar:
# __doc__,sys,datetime
# urllib:
#
# urllib.parse:
# __doc__,re,sys
# unicodedata:
#
# email._parseaddr:
# __doc__,__all__,time
# email.message:
# __doc__,__all__,re
# uu:
# __doc__,binascii,os
# optparse:
# __doc__,__version__,__all__
# email._encoded_words:
# __doc__,re,base64
# email.iterators:
# __doc__,__all__,sys
# email.generator:
# __doc__,__all__,re
# email.policy:
# __doc__,re,sys
# email.headerregistry:
# __doc__,MappingProxyType,utils
# email._header_value_parser:
# __doc__,re,sys
# email.contentmanager:
# binascii,email,quoprimime
# hmac:
# __doc__,_warnings,compare_digest
# ssl:
# __doc__,sys,os
# _ssl:
#
# win32evtlogutil:
# __doc__,win32api,win32con
# win32api:
#
# win32con:
# WINVER,WM_USER,PY_0U
# winerror:
# __doc__,TRUST_E_PROVIDER_UNKNOWN,TRUST_E_ACTION_UNKNOWN
# win32evtlog:
#
# http:
# IntEnum,__all__,HTTPStatus
# http.client:
# __doc__,email,http
# pyreadline.clipboard:
# print_function,unicode_literals,absolute_import
# pyreadline.clipboard.ironpython_clipboard:
# print_function,unicode_literals,absolute_import
# pyreadline.clipboard.no_clipboard:
# print_function,unicode_literals,absolute_import
# pyreadline.clipboard.win32_clipboard:
# print_function,unicode_literals,absolute_import
# ctypes:
# __doc__,_os,_sys
# _ctypes:
#
# ctypes._endian:
# sys,__doc__,_os
# ctypes.wintypes:
# ctypes,BYTE,WORD
# pyreadline.keysyms:
# print_function,unicode_literals,absolute_import
# pyreadline.keysyms.winconstants:
# print_function,unicode_literals,absolute_import
# pyreadline.keysyms.ironpython_keysyms:
# print_function,unicode_literals,absolute_import
# pyreadline.keysyms.common:
# print_function,unicode_literals,absolute_import
# pyreadline.keysyms.keysyms:
# print_function,unicode_literals,absolute_import
# pyreadline.lineeditor:
# print_function,unicode_literals,absolute_import
# pyreadline.modes:
# print_function,unicode_literals,absolute_import
# pyreadline.modes.emacs:
# print_function,unicode_literals,absolute_import
# pyreadline.lineeditor.lineobj:
# print_function,unicode_literals,absolute_import
# pyreadline.lineeditor.wordmatcher:
# print_function,unicode_literals,absolute_import
# pyreadline.lineeditor.history:
# print_function,unicode_literals,absolute_import
# pyreadline.modes.basemode:
# print_function,unicode_literals,absolute_import
# glob:
# __doc__,os,re
# pyreadline.error:
# print_function,unicode_literals,absolute_import
# pyreadline.modes.notemacs:
# print_function,unicode_literals,absolute_import
# pyreadline.modes.vi:
# print_function,unicode_literals,absolute_import
# tempfile:
# __doc__,__all__,_functools
# shutil:
# __doc__,os,sys
# zlib:
#
# bz2:
# __doc__,__all__,__author__
# _compression:
# __doc__,io,BUFFER_SIZE
# _bz2:
#
# lzma:
# __doc__,__all__,builtins
# _lzma:
#
# nt:
#
# tarfile:
# __doc__,version,__author__
# gzip:
# __doc__,struct,sys
# zipfile:
# __doc__,io,os
# importlib.util:
# __doc__,abc,module_from_spec
# importlib.abc:
# __doc__,_bootstrap,_bootstrap_external
# py_compile:
# __doc__,enum,importlib
# pyreadline.console:
# print_function,unicode_literals,absolute_import
# pyreadline.console.ironpython_console:
# print_function,unicode_literals,absolute_import
# pyreadline.console.event:
# print_function,unicode_literals,absolute_import
# pyreadline.console.ansi:
# print_function,unicode_literals,absolute_import
# pyreadline.rlmain:
# print_function,unicode_literals,absolute_import
# pyreadline.release:
# print_function,unicode_literals,absolute_import
# bdb:
# __doc__,fnmatch,sys
# reprlib:
# __doc__,__all__,builtins
# code:
# __doc__,sys,traceback
# codeop:
# __doc__,__future__,_features
# signal:
# _signal,_wraps,_IntEnum
# _signal:
#
# shlex:
# __doc__,os,re
# runpy:
# __doc__,sys,importlib
# pkgutil:
# __doc__,namedtuple,simplegeneric
# zipimport:
#
# marshal:
#
# pydoc:
# __doc__,__all__,__author__
# platform:
# __doc__,__copyright__,__version__
# subprocess:
# __doc__,sys,_mswindows
# msvcrt:
#
# winreg:
#
# plistlib:
# __doc__,__all__,binascii
# xml:
# __doc__,__all__
# xml.parsers:
# __doc__
# xml.parsers.expat:
# __doc__,sys
# pyexpat:
#
# sysconfig:
# __doc__,os,sys
# _osx_support:
# __doc__,os,re
# distutils:
# __doc__,sys,__version__
# distutils.log:
# __doc__,DEBUG,INFO
# tty:
# __doc__,__all__,IFLAG
# pydoc_data:
#
# pydoc_data.topics:
# topics
# http.server:
# __doc__,__version__,__all__
# html:
# __doc__,_re,_html5
# html.entities:
# __doc__,__all__,name2codepoint
# mimetypes:
# __doc__,os,sys
# socketserver:
# __doc__,__version__,socket
# webbrowser:
# __doc__,os,shlex
# unittest:
# __doc__,__all__,__unittest
# unittest.result:
# __doc__,io,sys
# unittest.util:
# __doc__,namedtuple,Counter
# unittest.case:
# __doc__,sys,functools
# unittest.suite:
# __doc__,sys,case
# unittest.loader:
# __doc__,os,re
# unittest.main:
# __doc__,sys,argparse
# unittest.runner:
# __doc__,sys,time
# unittest.signals:
# signal,weakref,wraps
# typing:
# __doc__,abc,abstractmethod
# sre_compile:
# __doc__,_sre,sre_parse
# _sre:
#
# sre_parse:
# __doc__,MAGIC,MAXREPEAT
# sre_constants:
# __doc__,MAGIC,MAXREPEAT
# ntpath:
# __doc__,curdir,pardir
# multiprocessing.process:
# __all__,os,sys
# multiprocessing.util:
# os,itertools,sys
# multiprocessing.reduction:
# ABCMeta,copyreg,functools
# array:
#
# multiprocessing.resource_sharer:
# os,signal,socket
# multiprocessing.connection:
# __all__,io,os
# _multiprocessing:
#
# xmlrpc:
#
# xmlrpc.client:
# __doc__,base64,sys
# decimal:
# __doc__,__version__,__libmpdec_version__
# _decimal:
#
# _pydecimal:
# __doc__,__all__,__xname__
# numbers:
# __doc__,ABCMeta,abstractmethod
# contextvars:
# Context,ContextVar,Token
# _contextvars:
#
# multiprocessing.managers:
# __all__,sys,threading
# multiprocessing.pool:
# __all__,threading,queue
# multiprocessing.dummy:
# __all__,threading,sys
# multiprocessing.dummy.connection:
# __all__,Queue,families
# multiprocessing.synchronize:
# __all__,threading,sys
# multiprocessing.semaphore_tracker:
# os,signal,sys
# multiprocessing.spawn:
# os,sys,runpy
# multiprocessing.heap:
# bisect,mmap,os
# mmap:
#
# multiprocessing.queues:
# __all__,sys,os
# multiprocessing.sharedctypes:
# ctypes,weakref,heap
# multiprocessing.forkserver:
# errno,os,selectors
# multiprocessing.popen_fork:
# os,sys,signal
# multiprocessing.popen_spawn_posix:
# io,os,reduction
# multiprocessing.popen_forkserver:
# io,os,reduction
# multiprocessing.popen_spawn_win32:
# os,msvcrt,signal
# multiprocessing.Pool:
# __all__,threading,queue
# --------------------------------------------------
# Modules not imported:
# posix
# pwd
# collections.namedtuple
# os.path
# org.python.core
# _frozen_importlib
# _frozen_importlib_external
# collections.OrderedDict
# collections.deque
# collections.ChainMap
# StringIO
# clr
# System.Windows.Forms.Clipboard
# System
# sets
# startup
# ctypes.windll
# grp
# IronPythonConsole
# pyreadline.keysyms.make_keysym
# pyreadline.keysyms.make_keyinfo
# pyreadline.keysyms.make_KeyPress
# pyreadline.keysyms.make_KeyPress_from_keydescr
# console
# modes.editingmodes
# _posixsubprocess
# _winreg
# java.lang
# vms_lib
# termios
# http.HTTPStatus
# collections.Counter
# multiprocessing.AuthenticationError
# multiprocessing.BufferTooShort
# multiprocessing.get_context
# multiprocessing.TimeoutError
# dummy.Process
# multiprocessing.get_start_method
# multiprocessing.set_start_method
